# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = time.ctime(city_weather['dt'])
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass           
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | papatowai
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | stanley
# Processing Record 5 of Set 1 | polyarnyy
# Processing Record 6 of Set 1 | homer
# Processing Record 7 of Set 1 | puerto natales
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | valparaiso
# Processing Record 10 of Set 1 | west island
# Processing Record 11 of Set 1 | korla
# Processing Record 12 of Set 1 | motygino
# Processing Record 13 of Set 1 | freeport
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | beaufort west
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | ko pha ngan
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | muzayri'
# City not found. Skipping...
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | nabire
# Processing Record 24 of Set 1 | budva
# Processing Record 25 of Set 1 | port saint john's
# Processing Record 26 of Set 1 | paragominas
# Processing Record 27 of Set 1 | kaohsiung
# Processing Record 28 of Set 1 | olonkinbyen
# Processing Record 29 of Set 1 | udachny
# Processing Record 30 of Set 1 | zangguy
# City not found. Skipping...
# Processing Record 31 of Set 1 | carauari
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | belomorsk
# Processing Record 34 of Set 1 | ta`u
# Processing Record 35 of Set 1 | ylivieska
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | uturoa
# Processing Record 38 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 39 of Set 1 | westport
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | codrington
# Processing Record 42 of Set 1 | sorong
# Processing Record 43 of Set 1 | chonchi
# Processing Record 44 of Set 1 | posto fiscal rolim de moura
# Processing Record 45 of Set 1 | itambacuri
# Processing Record 46 of Set 1 | yuzhno-kurilsk
# Processing Record 47 of Set 1 | nemuro
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | kwang binh
# Processing Record 50 of Set 1 | enewetak
# Processing Record 0 of Set 2 | tofol
# Processing Record 1 of Set 2 | mount pearl
# Processing Record 2 of Set 2 | edinburgh of the seven seas
# Processing Record 3 of Set 2 | castillos
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | katipunan
# Processing Record 6 of Set 2 | labasa
# Processing Record 7 of Set 2 | olds
# Processing Record 8 of Set 2 | gunjur
# Processing Record 9 of Set 2 | el alto
# Processing Record 10 of Set 2 | capao da canoa
# Processing Record 11 of Set 2 | sidi ifni
# Processing Record 12 of Set 2 | bikenibeu village
# Processing Record 13 of Set 2 | kisanga
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | grytviken
# Processing Record 17 of Set 2 | boulsa
# Processing Record 18 of Set 2 | adamstown
# Processing Record 19 of Set 2 | hawaiian paradise park
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | illapel
# Processing Record 22 of Set 2 | lihue
# Processing Record 23 of Set 2 | huarmey
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | inarajan village
# Processing Record 27 of Set 2 | urganch
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | badger
# Processing Record 30 of Set 2 | quimili
# Processing Record 31 of Set 2 | fale old settlement
# Processing Record 32 of Set 2 | auki
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | aykhal
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | baiao
# Processing Record 37 of Set 2 | linkoping
# Processing Record 38 of Set 2 | port mathurin
# Processing Record 39 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 40 of Set 2 | tachilek
# City not found. Skipping...
# Processing Record 41 of Set 2 | sur
# Processing Record 42 of Set 2 | phan rang-thap cham
# Processing Record 43 of Set 2 | papao
# Processing Record 44 of Set 2 | al 'alamayn
# City not found. Skipping...
# Processing Record 45 of Set 2 | bonito
# Processing Record 46 of Set 2 | uacu cungo
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | broken hill
# Processing Record 49 of Set 2 | paracuru
# Processing Record 0 of Set 3 | afaahiti
# Processing Record 1 of Set 3 | maragogi
# Processing Record 2 of Set 3 | sisimiut
# Processing Record 3 of Set 3 | colonia
# Processing Record 4 of Set 3 | sao jose da coroa grande
# Processing Record 5 of Set 3 | arica
# Processing Record 6 of Set 3 | mandasa
# Processing Record 7 of Set 3 | arno
# Processing Record 8 of Set 3 | mastic beach
# Processing Record 9 of Set 3 | arteche
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | ishigaki
# Processing Record 12 of Set 3 | igarka
# Processing Record 13 of Set 3 | mong cai
# City not found. Skipping...
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | kirkwall
# Processing Record 16 of Set 3 | sola
# Processing Record 17 of Set 3 | puerto baquerizo moreno
# Processing Record 18 of Set 3 | illizi
# Processing Record 19 of Set 3 | bilibino
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | susuman
# Processing Record 22 of Set 3 | isafjordur
# Processing Record 23 of Set 3 | pitkyaranta
# Processing Record 24 of Set 3 | praia da vitoria
# Processing Record 25 of Set 3 | zhosaly
# Processing Record 26 of Set 3 | iskateley
# Processing Record 27 of Set 3 | hadibu
# Processing Record 28 of Set 3 | cumnock
# Processing Record 29 of Set 3 | leme
# Processing Record 30 of Set 3 | katsuren-haebaru
# Processing Record 31 of Set 3 | puerto madryn
# Processing Record 32 of Set 3 | margaret river
# Processing Record 33 of Set 3 | san antonio de pale
# Processing Record 34 of Set 3 | holualoa
# Processing Record 35 of Set 3 | vadso
# Processing Record 36 of Set 3 | saldanha
# Processing Record 37 of Set 3 | qaqortoq
# Processing Record 38 of Set 3 | ola
# Processing Record 39 of Set 3 | quelimane
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | weno
# Processing Record 42 of Set 3 | atafu village
# Processing Record 43 of Set 3 | kabo
# Processing Record 44 of Set 3 | puerto deseado
# Processing Record 45 of Set 3 | kapuskasing
# Processing Record 46 of Set 3 | tolanaro
# Processing Record 47 of Set 3 | tazovsky
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 0 of Set 4 | uromi
# Processing Record 1 of Set 4 | aldama
# Processing Record 2 of Set 4 | kapyl'
# City not found. Skipping...
# Processing Record 3 of Set 4 | keflavik
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | charles city
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | kikwit
# Processing Record 8 of Set 4 | la paz
# Processing Record 9 of Set 4 | port douglas
# Processing Record 10 of Set 4 | mulayjah
# Processing Record 11 of Set 4 | hatillo
# Processing Record 12 of Set 4 | nova sintra
# Processing Record 13 of Set 4 | chibougamau
# Processing Record 14 of Set 4 | mandiana
# Processing Record 15 of Set 4 | tura
# Processing Record 16 of Set 4 | naze
# Processing Record 17 of Set 4 | brookings
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | nishinoomote
# Processing Record 20 of Set 4 | st. john's
# Processing Record 21 of Set 4 | taoudenni
# Processing Record 22 of Set 4 | pandan
# Processing Record 23 of Set 4 | touros
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 26 of Set 4 | muravlenko
# Processing Record 27 of Set 4 | agua preta
# Processing Record 28 of Set 4 | feres
# Processing Record 29 of Set 4 | hailar
# Processing Record 30 of Set 4 | birjand
# Processing Record 31 of Set 4 | ma'rib
# Processing Record 32 of Set 4 | kununurra
# Processing Record 33 of Set 4 | tual
# Processing Record 34 of Set 4 | altai
# Processing Record 35 of Set 4 | wanning
# Processing Record 36 of Set 4 | brisas de zicatela
# Processing Record 37 of Set 4 | jamestown
# Processing Record 38 of Set 4 | hesla
# Processing Record 39 of Set 4 | richards bay
# Processing Record 40 of Set 4 | chincha alta
# Processing Record 41 of Set 4 | firmat
# Processing Record 42 of Set 4 | copala
# Processing Record 43 of Set 4 | argostolion
# Processing Record 44 of Set 4 | kapa'a
# Processing Record 45 of Set 4 | matlang
# Processing Record 46 of Set 4 | otacilio costa
# Processing Record 47 of Set 4 | kampene
# Processing Record 48 of Set 4 | lycksele
# Processing Record 49 of Set 4 | yokadouma
# Processing Record 0 of Set 5 | vorgashor
# Processing Record 1 of Set 5 | natal
# Processing Record 2 of Set 5 | ust-nera
# Processing Record 3 of Set 5 | utrik
# Processing Record 4 of Set 5 | wailua homesteads
# Processing Record 5 of Set 5 | kolonia town
# Processing Record 6 of Set 5 | badr hunayn
# Processing Record 7 of Set 5 | invercargill
# Processing Record 8 of Set 5 | rouissat
# Processing Record 9 of Set 5 | tucumcari
# Processing Record 10 of Set 5 | berdigestyakh
# Processing Record 11 of Set 5 | cheremkhovo
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | hassi messaoud
# Processing Record 14 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 15 of Set 5 | lerwick
# Processing Record 16 of Set 5 | kayangel
# Processing Record 17 of Set 5 | zhanaozen
# Processing Record 18 of Set 5 | hoeilaart
# Processing Record 19 of Set 5 | riverton
# Processing Record 20 of Set 5 | cide
# Processing Record 21 of Set 5 | vernon
# Processing Record 22 of Set 5 | djambala
# Processing Record 23 of Set 5 | krutinka
# Processing Record 24 of Set 5 | santa cruz de tenerife
# Processing Record 25 of Set 5 | wenchang
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | salekhard
# Processing Record 28 of Set 5 | al jubayl
# Processing Record 29 of Set 5 | georgetown
# Processing Record 30 of Set 5 | thunder bay
# Processing Record 31 of Set 5 | jezowe
# Processing Record 32 of Set 5 | inirida
# Processing Record 33 of Set 5 | kiunga
# Processing Record 34 of Set 5 | selfoss
# Processing Record 35 of Set 5 | ziro
# Processing Record 36 of Set 5 | ephraim
# Processing Record 37 of Set 5 | kone
# Processing Record 38 of Set 5 | tingi
# Processing Record 39 of Set 5 | muisne
# Processing Record 40 of Set 5 | acapulco de juarez
# Processing Record 41 of Set 5 | nadym
# Processing Record 42 of Set 5 | mhamid
# Processing Record 43 of Set 5 | monrovia
# Processing Record 44 of Set 5 | ulladulla
# Processing Record 45 of Set 5 | guaruja
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | zemio
# Processing Record 48 of Set 5 | leava
# Processing Record 49 of Set 5 | dudinka
# Processing Record 0 of Set 6 | anadyr
# Processing Record 1 of Set 6 | namibe
# Processing Record 2 of Set 6 | demopolis
# Processing Record 3 of Set 6 | sinan
# Processing Record 4 of Set 6 | ayabaca
# Processing Record 5 of Set 6 | willowmore
# Processing Record 6 of Set 6 | la gi
# Processing Record 7 of Set 6 | bangjun
# Processing Record 8 of Set 6 | crucecita
# Processing Record 9 of Set 6 | gap
# Processing Record 10 of Set 6 | kyren
# Processing Record 11 of Set 6 | bor
# Processing Record 12 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 13 of Set 6 | ciudad lazaro cardenas
# Processing Record 14 of Set 6 | siwa oasis
# Processing Record 15 of Set 6 | kalevala
# Processing Record 16 of Set 6 | la passe
# Processing Record 17 of Set 6 | necochea
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | sanliurfa
# Processing Record 20 of Set 6 | kourou
# Processing Record 21 of Set 6 | robore
# Processing Record 22 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 23 of Set 6 | manokwari
# Processing Record 24 of Set 6 | palmer
# Processing Record 25 of Set 6 | usogorsk
# Processing Record 26 of Set 6 | miches
# Processing Record 27 of Set 6 | tamandare
# Processing Record 28 of Set 6 | bodaybo
# Processing Record 29 of Set 6 | yinchuan
# Processing Record 30 of Set 6 | taghazout
# Processing Record 31 of Set 6 | mana
# Processing Record 32 of Set 6 | timbuktu
# Processing Record 33 of Set 6 | vieux-habitants
# Processing Record 34 of Set 6 | kerikeri
# Processing Record 35 of Set 6 | sukhodol
# Processing Record 36 of Set 6 | poronaysk
# Processing Record 37 of Set 6 | cole harbour
# Processing Record 38 of Set 6 | bel ombre
# Processing Record 39 of Set 6 | abepura
# Processing Record 40 of Set 6 | tekane
# City not found. Skipping...
# Processing Record 41 of Set 6 | lapaha
# City not found. Skipping...
# Processing Record 42 of Set 6 | piacabucu
# Processing Record 43 of Set 6 | tecate
# Processing Record 44 of Set 6 | tarrafal
# Processing Record 45 of Set 6 | tharangambadi
# Processing Record 46 of Set 6 | turpan
# Processing Record 47 of Set 6 | bayan nur
# City not found. Skipping...
# Processing Record 48 of Set 6 | sibu
# Processing Record 49 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 0 of Set 7 | lata
# Processing Record 1 of Set 7 | turkmenbasy
# Processing Record 2 of Set 7 | canico
# Processing Record 3 of Set 7 | fonadhoo
# City not found. Skipping...
# Processing Record 4 of Set 7 | onda
# Processing Record 5 of Set 7 | palu
# Processing Record 6 of Set 7 | constantia
# Processing Record 7 of Set 7 | chiredzi
# Processing Record 8 of Set 7 | tazacorte
# Processing Record 9 of Set 7 | lluta
# Processing Record 10 of Set 7 | catriel
# Processing Record 11 of Set 7 | vyazemskiy
# Processing Record 12 of Set 7 | aasiaat
# Processing Record 13 of Set 7 | kincardine
# Processing Record 14 of Set 7 | ilha de mocambique
# Processing Record 15 of Set 7 | miracema do tocantins
# Processing Record 16 of Set 7 | kimberley
# Processing Record 17 of Set 7 | ongole
# Processing Record 18 of Set 7 | ghat
# Processing Record 19 of Set 7 | sishilichengzi
# City not found. Skipping...
# Processing Record 20 of Set 7 | pueblo nuevo
# Processing Record 21 of Set 7 | nizhniy kuranakh
# Processing Record 22 of Set 7 | pokhara
# Processing Record 23 of Set 7 | broome
# Processing Record 24 of Set 7 | sairang
# Processing Record 25 of Set 7 | toliara
# Processing Record 26 of Set 7 | huangmei
# Processing Record 27 of Set 7 | pontes e lacerda
# Processing Record 28 of Set 7 | pimentel
# Processing Record 29 of Set 7 | apaxco de ocampo
# Processing Record 30 of Set 7 | floro
# Processing Record 31 of Set 7 | kalaleh
# Processing Record 32 of Set 7 | newman
# Processing Record 33 of Set 7 | suntar
# Processing Record 34 of Set 7 | pathein
# Processing Record 35 of Set 7 | fortuna
# Processing Record 36 of Set 7 | katsuura
# Processing Record 37 of Set 7 | lamu
# Processing Record 38 of Set 7 | zouerate
# Processing Record 39 of Set 7 | akrehamn
# Processing Record 40 of Set 7 | berezovo
# Processing Record 41 of Set 7 | andalusia
# Processing Record 42 of Set 7 | kristiansund
# Processing Record 43 of Set 7 | boquira
# Processing Record 44 of Set 7 | kedrovyy
# Processing Record 45 of Set 7 | vilyuchinsk
# Processing Record 46 of Set 7 | burang
# Processing Record 47 of Set 7 | madison
# Processing Record 48 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 7 | tezonapa
# Processing Record 0 of Set 8 | mil'kovo
# Processing Record 1 of Set 8 | bamboo flat
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | machico
# Processing Record 4 of Set 8 | antsiranana
# Processing Record 5 of Set 8 | ancud
# Processing Record 6 of Set 8 | remire-montjoly
# Processing Record 7 of Set 8 | new norfolk
# Processing Record 8 of Set 8 | coahuayana de hidalgo
# Processing Record 9 of Set 8 | saipan
# Processing Record 10 of Set 8 | sukhoy log
# Processing Record 11 of Set 8 | buala
# Processing Record 12 of Set 8 | bo phloi
# Processing Record 13 of Set 8 | fallon
# Processing Record 14 of Set 8 | miquelon
# Processing Record 15 of Set 8 | pinhao
# Processing Record 16 of Set 8 | maun
# Processing Record 17 of Set 8 | benguela
# Processing Record 18 of Set 8 | alakurtti
# Processing Record 19 of Set 8 | puerto colombia
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | brigantine
# Processing Record 22 of Set 8 | al wafrah
# Processing Record 23 of Set 8 | santa marta
# Processing Record 24 of Set 8 | fuding
# Processing Record 25 of Set 8 | margate
# Processing Record 26 of Set 8 | crane
# Processing Record 27 of Set 8 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 28 of Set 8 | yoloten
# Processing Record 29 of Set 8 | klyuchi
# Processing Record 30 of Set 8 | maintirano
# Processing Record 31 of Set 8 | bonthe
# Processing Record 32 of Set 8 | island harbour
# Processing Record 33 of Set 8 | nadi
# Processing Record 34 of Set 8 | port glaud
# City not found. Skipping...
# Processing Record 35 of Set 8 | reiskirchen
# Processing Record 36 of Set 8 | langepas
# Processing Record 37 of Set 8 | queenstown
# Processing Record 38 of Set 8 | dzhangala
# Processing Record 39 of Set 8 | beloyarskiy
# Processing Record 40 of Set 8 | khandyga
# Processing Record 41 of Set 8 | sault ste. marie
# Processing Record 42 of Set 8 | mahina
# Processing Record 43 of Set 8 | soanindrariny
# City not found. Skipping...
# Processing Record 44 of Set 8 | swan hill
# Processing Record 45 of Set 8 | rongelap
# Processing Record 46 of Set 8 | santana
# Processing Record 47 of Set 8 | matoury
# Processing Record 48 of Set 8 | hepingjie
# Processing Record 49 of Set 8 | goulburn
# Processing Record 0 of Set 9 | tysmenytsya
# Processing Record 1 of Set 9 | imam qasim
# Processing Record 2 of Set 9 | berezovyy
# Processing Record 3 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 9 | zaozersk
# Processing Record 5 of Set 9 | richfield
# Processing Record 6 of Set 9 | galliano
# Processing Record 7 of Set 9 | selkirk
# Processing Record 8 of Set 9 | port-vila
# Processing Record 9 of Set 9 | puerto san jose
# Processing Record 10 of Set 9 | rosa zarate
# Processing Record 11 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 9 | abengourou
# Processing Record 13 of Set 9 | concepcion
# Processing Record 14 of Set 9 | nuuk
# Processing Record 15 of Set 9 | ha'il
# Processing Record 16 of Set 9 | chokwe
# Processing Record 17 of Set 9 | juan griego
# Processing Record 18 of Set 9 | amga
# Processing Record 19 of Set 9 | shingu
# Processing Record 20 of Set 9 | kamphaeng phet
# Processing Record 21 of Set 9 | nizhneangarsk
# Processing Record 22 of Set 9 | timimoun
# Processing Record 23 of Set 9 | arraial do cabo
# Processing Record 24 of Set 9 | sandnessjoen
# Processing Record 25 of Set 9 | adygeysk
# Processing Record 26 of Set 9 | djenne
# Processing Record 27 of Set 9 | nova vicosa
# Processing Record 28 of Set 9 | checker hall
# City not found. Skipping...
# Processing Record 29 of Set 9 | camocim
# Processing Record 30 of Set 9 | mugia
# Processing Record 31 of Set 9 | kokopo
# Processing Record 32 of Set 9 | kyzyl-suu
# Processing Record 33 of Set 9 | okhotsk
# Processing Record 34 of Set 9 | lodwar
# Processing Record 35 of Set 9 | sechura
# Processing Record 36 of Set 9 | sidi salim
# Processing Record 37 of Set 9 | ain taya
# Processing Record 38 of Set 9 | mejit
# Processing Record 39 of Set 9 | saudarkrokur
# Processing Record 40 of Set 9 | erenhot
# Processing Record 41 of Set 9 | nguigmi
# Processing Record 42 of Set 9 | midvagur
# Processing Record 43 of Set 9 | cekerek
# Processing Record 44 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 45 of Set 9 | skowhegan
# Processing Record 46 of Set 9 | madalena
# Processing Record 47 of Set 9 | corinto
# Processing Record 48 of Set 9 | duyun
# Processing Record 49 of Set 9 | patterson
# Processing Record 0 of Set 10 | akureyri
# Processing Record 1 of Set 10 | kingston
# Processing Record 2 of Set 10 | lucapa
# Processing Record 3 of Set 10 | bocas del toro
# Processing Record 4 of Set 10 | tralee
# Processing Record 5 of Set 10 | lanskroun
# Processing Record 6 of Set 10 | nikko
# Processing Record 7 of Set 10 | pontiac
# Processing Record 8 of Set 10 | flying fish cove
# Processing Record 9 of Set 10 | shalqar
# Processing Record 10 of Set 10 | tsiombe
# Processing Record 11 of Set 10 | port lavaca
# Processing Record 12 of Set 10 | fort mcmurray
# Processing Record 13 of Set 10 | lys'va
# Processing Record 14 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 15 of Set 10 | abay
# Processing Record 16 of Set 10 | huicungo
# Processing Record 17 of Set 10 | quixeramobim
# Processing Record 18 of Set 10 | saskatoon
# Processing Record 19 of Set 10 | nar'yan-mar
# Processing Record 20 of Set 10 | sao gabriel da cachoeira
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | yakutsk
# Processing Record 23 of Set 10 | buckeye
# Processing Record 24 of Set 10 | talnakh
# Processing Record 25 of Set 10 | lagoa santa
# Processing Record 26 of Set 10 | sokol
# Processing Record 27 of Set 10 | port shepstone
# Processing Record 28 of Set 10 | santa rosa misiones
# Processing Record 29 of Set 10 | shangri-la
# City not found. Skipping...
# Processing Record 30 of Set 10 | santa elena de uairen
# Processing Record 31 of Set 10 | qulsary
# Processing Record 32 of Set 10 | sao joao da barra
# Processing Record 33 of Set 10 | juan aldama
# Processing Record 34 of Set 10 | plastun
# Processing Record 35 of Set 10 | kooringal
# Processing Record 36 of Set 10 | ilheus
# Processing Record 37 of Set 10 | dryden
# Processing Record 38 of Set 10 | ivdel'
# Processing Record 39 of Set 10 | uglegorsk
# Processing Record 40 of Set 10 | dongola
# Processing Record 41 of Set 10 | ar rass
# Processing Record 42 of Set 10 | fisterra
# Processing Record 43 of Set 10 | ambodivoara
# City not found. Skipping...
# Processing Record 44 of Set 10 | soligalich
# Processing Record 45 of Set 10 | una
# Processing Record 46 of Set 10 | celestun
# Processing Record 47 of Set 10 | zajas
# Processing Record 48 of Set 10 | diego de almagro
# Processing Record 49 of Set 10 | ketchikan
# Processing Record 0 of Set 11 | tamanrasset
# Processing Record 1 of Set 11 | zapolyarnyy
# Processing Record 2 of Set 11 | khabarovsk
# Processing Record 3 of Set 11 | amos
# Processing Record 4 of Set 11 | volosovo
# Processing Record 5 of Set 11 | mount isa
# Processing Record 6 of Set 11 | port hedland
# Processing Record 7 of Set 11 | surab
# Processing Record 8 of Set 11 | dimbokro
# Processing Record 9 of Set 11 | taiyuan
# Processing Record 10 of Set 11 | kimbe
# Processing Record 11 of Set 11 | hammerfest
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | kavieng
# Processing Record 14 of Set 11 | labrador city
# Processing Record 15 of Set 11 | kingscliff
# Processing Record 16 of Set 11 | embarcacion
# Processing Record 17 of Set 11 | deniliquin
# Processing Record 18 of Set 11 | gadzhiyevo
# Processing Record 19 of Set 11 | talodi
# Processing Record 20 of Set 11 | haiku-pauwela
# Processing Record 21 of Set 11 | sao raimundo das mangabeiras
# Processing Record 22 of Set 11 | tubarjal
# Processing Record 23 of Set 11 | sidareja
# Processing Record 24 of Set 11 | el oued
# Processing Record 25 of Set 11 | saundatti
# Processing Record 26 of Set 11 | oroqen zizhiqi
# Processing Record 27 of Set 11 | chopda
# Processing Record 28 of Set 11 | figeac
# Processing Record 29 of Set 11 | wajir
# Processing Record 30 of Set 11 | bandarbeyla
# Processing Record 31 of Set 11 | saint-philippe
# Processing Record 32 of Set 11 | atar
# Processing Record 33 of Set 11 | phalaborwa
# Processing Record 34 of Set 11 | sovetskiy
# Processing Record 35 of Set 11 | les cayes
# Processing Record 36 of Set 11 | lockwood
# Processing Record 37 of Set 11 | mapimi
# Processing Record 38 of Set 11 | tomatlan
# Processing Record 39 of Set 11 | gwanda
# Processing Record 40 of Set 11 | grahamstown
# Processing Record 41 of Set 11 | eskisehir
# Processing Record 42 of Set 11 | northam
# Processing Record 43 of Set 11 | la foa
# Processing Record 44 of Set 11 | lorengau
# Processing Record 45 of Set 11 | pemangkat
# Processing Record 46 of Set 11 | lewiston orchards
# Processing Record 47 of Set 11 | vilyuysk
# Processing Record 48 of Set 11 | al kharijah
# Processing Record 49 of Set 11 | taro
# Processing Record 0 of Set 12 | san mateo del mar
# Processing Record 1 of Set 12 | punta del este
# Processing Record 2 of Set 12 | acarau
# Processing Record 3 of Set 12 | colac
# Processing Record 4 of Set 12 | pitiquito
# Processing Record 5 of Set 12 | nikolayevsk-on-amure
# Processing Record 6 of Set 12 | upper grand lagoon
# Processing Record 7 of Set 12 | plouzane
# Processing Record 8 of Set 12 | geraldton
# Processing Record 9 of Set 12 | siuna
# Processing Record 10 of Set 12 | las tablas
# Processing Record 11 of Set 12 | isla vista
# Processing Record 12 of Set 12 | tan-tan
# Processing Record 13 of Set 12 | nagato
# Processing Record 14 of Set 12 | swedru
# Processing Record 15 of Set 12 | san pedro pochutla
# Processing Record 16 of Set 12 | hluti
# Processing Record 17 of Set 12 | mathba
# Processing Record 18 of Set 12 | demyansk
# Processing Record 19 of Set 12 | fort st. john
# Processing Record 20 of Set 12 | port alfred
# Processing Record 21 of Set 12 | villa corzo
# Processing Record 22 of Set 12 | tharad
# Processing Record 23 of Set 12 | vozhega
# Processing Record 24 of Set 12 | ariquemes
# Processing Record 25 of Set 12 | cabedelo
# Processing Record 26 of Set 12 | laguna
# Processing Record 27 of Set 12 | sakaiminato
# Processing Record 28 of Set 12 | luanda
# Processing Record 29 of Set 12 | mossel bay
# Processing Record 30 of Set 12 | markaz-e hukumat-e darweshan
# Processing Record 31 of Set 12 | yarmouth
# Processing Record 32 of Set 12 | fort bragg
# Processing Record 33 of Set 12 | isangel
# Processing Record 34 of Set 12 | goundam
# Processing Record 35 of Set 12 | novaya lyalya
# Processing Record 36 of Set 12 | songea
# Processing Record 37 of Set 12 | bulolo
# Processing Record 38 of Set 12 | sarai ekdil
# Processing Record 39 of Set 12 | tobi village
# City not found. Skipping...
# Processing Record 40 of Set 12 | labytnangi
# Processing Record 41 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 42 of Set 12 | afif
# Processing Record 43 of Set 12 | bechar
# Processing Record 44 of Set 12 | moyynkum
# Processing Record 45 of Set 12 | kruisfontein
# Processing Record 46 of Set 12 | nouadhibou
# Processing Record 47 of Set 12 | talara
# Processing Record 48 of Set 12 | pangody
# Processing Record 49 of Set 12 | banyo
# Processing Record 0 of Set 13 | den burg
# Processing Record 1 of Set 13 | freetown
# Processing Record 2 of Set 13 | rikaze
# Processing Record 3 of Set 13 | vytegra
# Processing Record 4 of Set 13 | mogocha
# Processing Record 5 of Set 13 | kill devil hills
# Processing Record 6 of Set 13 | tra vinh
# Processing Record 7 of Set 13 | tashir
# Processing Record 8 of Set 13 | hermansverk
# Processing Record 9 of Set 13 | lodja
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    east london -33.0153   27.9116    295.67        60           0
# 1      papatowai -46.5619  169.4708    276.74        79          69
# 2  blackmans bay -43.0167  147.3167    282.22        66           0
# 3        stanley  54.8680   -1.6985    287.75        81          20
# 4      polyarnyy  69.1989   33.4478    276.43        66          80
#
#    Wind Speed Country                      Date
# 0        8.75      ZA  Mon Oct  2 10:51:49 2023
# 1        3.02      NZ  Mon Oct  2 10:51:55 2023
# 2        4.23      AU  Mon Oct  2 10:51:55 2023
# 3        2.57      GB  Mon Oct  2 10:48:29 2023
# 4        4.70      RU  Mon Oct  2 10:51:55 2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          east london -33.0153   27.9116    295.67        60           0
# 1            papatowai -46.5619  169.4708    276.74        79          69
# 2        blackmans bay -43.0167  147.3167    282.22        66           0
# 3              stanley  54.8680   -1.6985    287.75        81          20
# 4            polyarnyy  69.1989   33.4478    276.43        66          80
#
#          Wind Speed Country                      Date
# City_ID
# 0              8.75      ZA  Mon Oct  2 10:51:49 2023
# 1              3.02      NZ  Mon Oct  2 10:51:55 2023
# 2              4.23      AU  Mon Oct  2 10:51:55 2023
# 3              2.57      GB  Mon Oct  2 10:48:29 2023
# 4              4.70      RU  Mon Oct  2 10:51:55 2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
figure_1 = plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],marker="o",edgecolors="black",color='steelblue')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (2023-10-02)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
figure_2 = plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],marker="o",edgecolors="black",color='blue')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (2023-10-02)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
figure_3 = plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],marker="o",edgecolors="black",color='gold')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (2023-10-02)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
figure_4 = plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],marker="o",edgecolors="black",color='pink')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (2023-10-02)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg_plot(x,y,xlabel,ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    print(f"The r-value is: {rvalue}")
    regress_values = x * slope + intercept
    plt.scatter(x,y)
    plt.plot(x,regress_values,color = 'r')
    line_note = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
    plt.annotate(line_note,(min(x),min(regress_values)),color="red",fontsize=14)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3          stanley  54.8680   -1.6985    287.75        81          20
# 4        polyarnyy  69.1989   33.4478    276.43        66          80
# 5            homer  59.6425 -151.5483    282.08        88         100
# 10           korla  41.7597   86.1469    293.08        29          78
# 11        motygino  58.1831   94.7592    276.92        54         100
#
#          Wind Speed Country                      Date
# City_ID
# 3              2.57      GB  Mon Oct  2 10:48:29 2023
# 4              4.70      RU  Mon Oct  2 10:51:55 2023
# 5              2.06      US  Mon Oct  2 10:47:27 2023
# 10             2.51      CN  Mon Oct  2 10:51:56 2023
# 11             4.47      RU  Mon Oct  2 10:51:56 2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              east london -33.0153   27.9116    295.67        60           0
# 1                papatowai -46.5619  169.4708    276.74        79          69
# 2            blackmans bay -43.0167  147.3167    282.22        66           0
# 6           puerto natales -51.7236  -72.4875    279.40        61         100
# 7        port-aux-francais -49.3500   70.2167    274.01        61         100
#
#          Wind Speed Country                      Date
# City_ID
# 0              8.75      ZA  Mon Oct  2 10:51:49 2023
# 1              3.02      NZ  Mon Oct  2 10:51:55 2023
# 2              4.23      AU  Mon Oct  2 10:51:55 2023
# 6              7.20      CL  Mon Oct  2 10:51:56 2023
# 7             15.58      TF  Mon Oct  2 10:51:56 2023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg_plot(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"],"Latitude","Max Temp")
# Out:
# The r-value is: -0.8217245808988667

# %%
# Linear regression on Southern Hemisphere
linear_reg_plot(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"],"Latitude","Max Temp")
# Out:
# The r-value is: 0.69541148637525

# %% [markdown]
# **Discussion about the linear relationship:**
# Temperature vs. Latitude have very strong negative coorelation in Northern Hemisphere, and strong positive coorelation in southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg_plot(northern_hemi_df["Lat"],northern_hemi_df["Humidity"],"Latitude","Humidity")
# Out:
# The r-value is: 0.19035945533752924

# %%
# Southern Hemisphere
linear_reg_plot(southern_hemi_df["Lat"],southern_hemi_df["Humidity"],"Latitude","Humidity")
# Out:
# The r-value is: 0.15983988795246132

# %% [markdown]
# **Discussion about the linear relationship:** Humidity vs. Latitude have very weak positive coorelation in Northern Hemisphere and southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg_plot(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"],"Latitude","Cloudiness")
# Out:
# The r-value is: 0.09894199476017015

# %%
# Southern Hemisphere
linear_reg_plot(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"],"Latitude","Cloudiness")
# Out:
# The r-value is: 0.12221707799742426

# %% [markdown]
# **Discussion about the linear relationship:**
# Cloudiness vs. Latitude have very weak positive coorelation in Northern Hemisphere and southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg_plot(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"],"Latitude","Wind Speed")
# Out:
# The r-value is: 0.1511969859258151

# %%
# Southern Hemisphere
# Southern Hemisphere
linear_reg_plot(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"],"Latitude","Wind Speed")
# Out:
# The r-value is: -0.20244531810561048

# %% [markdown]
# **Discussion about the linear relationship:**
# Wind Speed vs. Latitude have very weak positive coorelation in Northern Hemisphere, and weak negative coorelation southern Hemisphere.
